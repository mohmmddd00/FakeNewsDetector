# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
# Out:
# /var/folders/3l/6kgdk0v10t3f71rs083jg3yw0000gn/T/ipykernel_43346/3211446311.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('/Users/mohamamdmustafa/Documents/Personal Projects/AI projects/Fake news detector/fake_or_real_news.csv')
data.head()
# Out:
#       id                                              title  \
# 0   8476                       You Can Smell Hillary’s Fear
# 1  10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2   3608        Kerry to go to Paris in gesture of sympathy
# 3  10142  Bernie supporters on Twitter erupt in anger ag...
# 4    875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data['fake'] = data['label'].apply(lambda x: 1 if x == "FAKE" else 0)
data
# Out:
#          id                                              title  \
# 0      8476                       You Can Smell Hillary’s Fear
# 1     10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2      3608        Kerry to go to Paris in gesture of sympathy
# 3     10142  Bernie supporters on Twitter erupt in anger ag...
# 4       875   The Battle of New York: Why This Primary Matters
# ...     ...                                                ...
# 6330   4490  State Department says it can't find emails fro...
# 6331   8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332   8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333   4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334   4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label  fake
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE     1
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE     1
# ...

# %%
data = data.drop("label", axis=1)
data.head()
# Out:
#       id                                              title  \
# 0   8476                       You Can Smell Hillary’s Fear
# 1  10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2   3608        Kerry to go to Paris in gesture of sympathy
# 3  10142  Bernie supporters on Twitter erupt in anger ag...
# 4    875   The Battle of New York: Why This Primary Matters
#
#                                                 text  fake
# 0  Daniel Greenfield, a Shillman Journalism Fello...     1
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...     1
# 2  U.S. Secretary of State John F. Kerry said Mon...     0
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...     1
# 4  It's primary day in New York and front-runners...     0

# %%
x = data['text']
y = data['fake']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
vectorizer = TfidfVectorizer(stop_words="english", max_df=0.7)
X_train_vectorized = vectorizer.fit_transform(X_train)
X_test_vectorized = vectorizer.transform(X_test)

# %%
clf = LinearSVC()
clf.fit(X_train_vectorized, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# LinearSVC()

# %%
clf.score(X_test_vectorized, y_test)
# Out:
# 0.9321231254932912

# %%
with open("myNews.txt", "w", encoding = "utf-8") as f: 
    f.write("nothing")

# %%
with open("myNews.txt", "r", encoding = "utf-8") as f:
    myNews = f.read()

# %%
print(myNews)
# Out:
# nothing

# %%
vectorizedText = vectorizer.transform([myNews])

# %%
clf.predict(vectorizedText)
# Out:
# array([1])
